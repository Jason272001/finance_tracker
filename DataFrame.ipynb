# %%
import pandas as pd

# %%
transactions = pd.DataFrame(columns=[
    "txn_id","date","type","amount","account_id","category","note","user_id"
])

# %%
accounts = pd.DataFrame(columns=[
    "account_id",
    "account_name",   # "Chase Checking", "Affirm Loan", "Car Loan"
    "account_type",   # "asset" or "debt"
    "group",
    "user_id"# optional: "cash", "bank", "credit", "loan", "investment"
])

# %%
daily_balances = pd.DataFrame(columns=[
    "dailyB_id",
    "date",
    "account_id",
    "balance",
    "type",
    "user_id"# assets: amount you own, debts: amount you owe
])

# %%
users = pd.DataFrame(columns=[
    "user_id",
    "name",
    "type",
    "password" 
])

# %%
transactions.to_csv("./data/transactions.csv",index=False)

# %%
accounts.to_csv("./data/accounts.csv",index=False)

# %%
daily_balances.to_csv("./data/daily_balances.csv",index=False)

# %%
users.to_csv("./data/users.csv",index=False)
